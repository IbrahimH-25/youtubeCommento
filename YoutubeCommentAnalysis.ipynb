# %% [markdown]
# # Importing dependancies

# %%
from pandas import read_csv
from googleapiclient.discovery import build
from numpy import array,unique

# %% [markdown]
# # Looking at data

# %%
data = r'youtoxic_english_1000.csv'
dataDF = read_csv(data)
dataDF
# Out:
#                 CommentId      VideoId  \
# 0    Ugg2KwwX0V8-aXgCoAEC  04kJtp6pVXI
# 1    Ugg2s5AzSPioEXgCoAEC  04kJtp6pVXI
# 2    Ugg3dWTOxryFfHgCoAEC  04kJtp6pVXI
# 3    Ugg7Gd006w1MPngCoAEC  04kJtp6pVXI
# 4    Ugg8FfTbbNF8IngCoAEC  04kJtp6pVXI
# ..                    ...          ...
# 995  Ugi5ADt10EdDz3gCoAEC  XRuCW80L9mA
# 996  Ugifh2DMhBbDkHgCoAEC  XRuCW80L9mA
# 997  Ugj_plbGBjjzYXgCoAEC  XRuCW80L9mA
# 998  Ugj0bah1De8xy3gCoAEC  XRuCW80L9mA
# 999  UgjBJKQSoQMQ6ngCoAEC  XRuCW80L9mA
#
#                                                   Text  IsToxic  IsAbusive  \
# 0    If only people would just take a step back and...    False      False
# 1    Law enforcement is not trained to shoot to app...     True       True
# 2    \nDont you reckon them 'black lives matter' ba...     True       True
# 3    There are a very large number of people who do...    False      False
# 4    The Arab dude is absolutely right, he should h...    False      False
# ...

# %%
catagoryList = dataDF.columns.values.tolist()[3:]
catagoryList
# Out:
# ['IsToxic',
#  'IsAbusive',
#  'IsThreat',
#  'IsProvocative',
#  'IsObscene',
#  'IsHatespeech',
#  'IsRacist',
#  'IsNationalist',
#  'IsSexist',
#  'IsHomophobic',
#  'IsReligiousHate',
#  'IsRadicalism']

# %% [markdown]
# # Creating a model

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
import pickle as pk

# %%
#vectorizing Column text
#starting with IsToxic
for colm in catagoryList:
    vecorModel = TfidfVectorizer(stop_words='english',max_features=1000)
    predictionGoal = colm
    x = dataDF['Text']
    y = dataDF[predictionGoal]
    print(dataDF[dataDF[predictionGoal] == True])

    vectorized_x = vecorModel.fit_transform(x)

    #making a randomforestcalssifier model
    rfc_model = RandomForestClassifier()
    rfc_model.fit(vectorized_x,y)
    rfcPkFile = pk.dump(rfc_model, open('pklFiles//%s_classifier.pkl'%predictionGoal,'wb'))
    vecPkFile = pk.dump(vecorModel,open('pklFiles//%s_vectorized_x.pkl'%predictionGoal,'wb'))
# Out:
#                       CommentId      VideoId  \
# 1          Ugg2s5AzSPioEXgCoAEC  04kJtp6pVXI
# 2          Ugg3dWTOxryFfHgCoAEC  04kJtp6pVXI
# 5          Ugg9a6FtoXdxmXgCoAEC  04kJtp6pVXI
# 6          Ugga9KzkNDGvlXgCoAEC  04kJtp6pVXI
# 7          UggBlIXoph7p-3gCoAEC  04kJtp6pVXI
# ..                          ...          ...
# 980  Ugw_Tl3Y0RyGKDAF7wp4AaABAg  TZxEyoplYbI
# 984  UgxSdrxMVF1TuxIq7VB4AaABAg  TZxEyoplYbI
# 986  UgyCg0SltxnjiXzfFdV4AaABAg  TZxEyoplYbI
# 993        UghGyVemEvDEqXgCoAEC  XRuCW80L9mA
# 996        Ugifh2DMhBbDkHgCoAEC  XRuCW80L9mA
#
#                                                   Text  IsToxic  IsAbusive  \
# 1    Law enforcement is not trained to shoot to app...     True       True
# 2    \nDont you reckon them 'black lives matter' ba...     True       True
# 5    here people his facebook is https://www.facebo...     True      False
# 6    Check out this you tube post. "Black man goes ...     True      False
# ...

# %% [markdown]
# # Running model

# %%
import pickle as pk

#creating a test data that will be the output
dataTestDF = dataDF[['CommentId','VideoId','Text']]
print(data)
# creating code for model


model = pk.load(open('yt_text_toxic_classifier.pkl','rb'))
tdif_vectorizer = pk.load(open('vectorized_x.pkl','rb'))
#lable_encoder = pk.load(open(''))

features = tdif_vectorizer.transform(dataTestDF['Text'])
predictions = model.predict(features)
#print(predictions)
dataTestDF[predictionGoal] = predictions
# Out:
# youtoxic_english_1000.csv
# C:\Users\ibrah\AppData\Local\Temp\ipykernel_16540\2684558162.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataTestDF[predictionGoal] = predictions

# %%
dataTestDF[dataTestDF[predictionGoal] == True]
# Out:
#                       CommentId      VideoId  \
# 1          Ugg2s5AzSPioEXgCoAEC  04kJtp6pVXI
# 2          Ugg3dWTOxryFfHgCoAEC  04kJtp6pVXI
# 5          Ugg9a6FtoXdxmXgCoAEC  04kJtp6pVXI
# 6          Ugga9KzkNDGvlXgCoAEC  04kJtp6pVXI
# 7          UggBlIXoph7p-3gCoAEC  04kJtp6pVXI
# ..                          ...          ...
# 984  UgxSdrxMVF1TuxIq7VB4AaABAg  TZxEyoplYbI
# 985  UgxVXEtXl4tiCP0shNt4AaABAg  TZxEyoplYbI
# 986  UgyCg0SltxnjiXzfFdV4AaABAg  TZxEyoplYbI
# 993        UghGyVemEvDEqXgCoAEC  XRuCW80L9mA
# 996        Ugifh2DMhBbDkHgCoAEC  XRuCW80L9mA
#
#                                                   Text  IsRadicalism
# 1    Law enforcement is not trained to shoot to app...          True
# 2    \nDont you reckon them 'black lives matter' ba...          True
# 5    here people his facebook is https://www.facebo...          True
# 6    Check out this you tube post. "Black man goes ...          True
# 7    I would LOVE to see this pussy go to Staten Is...          True
# ...

# %% [markdown]
# ----------------------------------------------

# %% [markdown]
# # testing with another video

# %%
#AIzaSyDszE0ynG7_rducSH1jbBJt3Y2Pwb6wGoY
API_Key = 'AIzaSyDszE0ynG7_rducSH1jbBJt3Y2Pwb6wGoY'
vidID = "04kJtp6pVXI"
youtube = build('youtube','v3',
                developerKey=API_Key)

video_response=youtube.comments().list(
#video_response=youtube.commentThreads().list(
  part='snippet,replies',
  videoId=vidID
).execute()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\ibrah\Documents\kaggle\youtubeCommento\YoutubeCommentAnalysis.ipynb Cell 14 in <cell line: 7>()
#       <a href='vscode-notebook-cell:/c%3A/Users/ibrah/Documents/kaggle/youtubeCommento/YoutubeCommentAnalysis.ipynb#X16sZmlsZQ%3D%3D?line=2'>3</a> vidID = "04kJtp6pVXI"
#       <a href='vscode-notebook-cell:/c%3A/Users/ibrah/Documents/kaggle/youtubeCommento/YoutubeCommentAnalysis.ipynb#X16sZmlsZQ%3D%3D?line=3'>4</a> youtube = build('youtube','v3',
#       <a href='vscode-notebook-cell:/c%3A/Users/ibrah/Documents/kaggle/youtubeCommento/YoutubeCommentAnalysis.ipynb#X16sZmlsZQ%3D%3D?line=4'>5</a>                 developerKey=API_Key)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ibrah/Documents/kaggle/youtubeCommento/YoutubeCommentAnalysis.ipynb#X16sZmlsZQ%3D%3D?line=6'>7</a> video_response=youtube.comments().list(
# ...

# %%
from pandas import DataFrame
commentList = []
commentListId = []
print(len(video_response(['items'])))
for item in video_response['items']:
    comment = item['snippet']['topLevelComment']['snippet']['textDisplay']
    commentID = item['snippet']['topLevelComment']['id']
    commentList.append(comment)
    commentListId.append(commentID)

DFTest = DataFrame(data = {'CommentId': commentListId,'VideoId': vidID,'Text': commentList})

    

item = video_response['items'][0]
comment = item['snippet']['topLevelComment']['snippet']['textDisplay']
commentID = item['snippet']['topLevelComment']['id']
print(comment,'\n',commentID)

#keyWords = comment.lower().replace(' you ','').replace(" it ",'').replace(" is ",'').split(' ')
DFTest
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\ibrah\Documents\kaggle\youtubeCommento\YoutubeCommentAnalysis.ipynb Cell 15 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/c%3A/Users/ibrah/Documents/kaggle/youtubeCommento/YoutubeCommentAnalysis.ipynb#X20sZmlsZQ%3D%3D?line=1'>2</a> commentList = []
#       <a href='vscode-notebook-cell:/c%3A/Users/ibrah/Documents/kaggle/youtubeCommento/YoutubeCommentAnalysis.ipynb#X20sZmlsZQ%3D%3D?line=2'>3</a> commentListId = []
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ibrah/Documents/kaggle/youtubeCommento/YoutubeCommentAnalysis.ipynb#X20sZmlsZQ%3D%3D?line=3'>4</a> print(len(video_response(['items'])))
#       <a href='vscode-notebook-cell:/c%3A/Users/ibrah/Documents/kaggle/youtubeCommento/YoutubeCommentAnalysis.ipynb#X20sZmlsZQ%3D%3D?line=4'>5</a> for item in video_response['items']:
# ...

# %%
dataTestDF = DFTest[['CommentId','VideoId','Text']]
for cat in catagoryList:
    import pickle as pk
    print(cat)
    #creating a test data that will be the output
    
    # creating code for model


    model = pk.load(open('%s_classifier.pkl'%cat,'rb'))
    tdif_vectorizer = pk.load(open('%s_vectorized_x.pkl'%cat,'rb'))
    #lable_encoder = pk.load(open(''))

    features = tdif_vectorizer.transform(dataTestDF['Text'])
    predictions = model.predict(features)
    #print(predictions)
    dataTestDF[cat] = predictions
dataTestDF
# Out:
# IsToxic
# IsAbusive
# IsThreat
# IsProvocative
# IsObscene
# IsHatespeech
# IsRacist
# IsNationalist
# IsSexist
# IsHomophobic
# IsReligiousHate
# IsRadicalism
#                      CommentId      VideoId  \
# 0   UgywD6uWEHCM-Eezrcd4AaABAg  04kJtp6pVXI
# 1   Ugyp6YArUZqZcJj-4bx4AaABAg  04kJtp6pVXI
# 2   UgztJB3vO_EKKvm_Crl4AaABAg  04kJtp6pVXI
# 3   UgxnZiT9z6CcOflMQOB4AaABAg  04kJtp6pVXI
# 4   Ugw8qBojiAjZ2NQHRSB4AaABAg  04kJtp6pVXI
# 5   Ugzo60u8HYqhjvm4xil4AaABAg  04kJtp6pVXI
# 6   UgzUMAB5w8QhIm_qsQt4AaABAg  04kJtp6pVXI
# 7   UgzYZgFyAt8o4ZhIT-F4AaABAg  04kJtp6pVXI
# 8   UgzTNhsWWdroxa-bn_Z4AaABAg  04kJtp6pVXI
# 9   UgyeHOlGzub3rFdbUmN4AaABAg  04kJtp6pVXI
# 10  UgzyY4WEPleMxj1R21h4AaABAg  04kJtp6pVXI
# 11  UgwDxaF8-rBk6Filvvd4AaABAg  04kJtp6pVXI
# 12  UgxeT5q9gXQyxX7b8r94AaABAg  04kJtp6pVXI
# 13  Ugw0hzc2gzr6sOoX-AB4AaABAg  04kJtp6pVXI
# 14  UgzqrEa254P4kJ2QJUd4AaABAg  04kJtp6pVXI
# 15  UgxNVzpMprGou0KuaC54AaABAg  04kJtp6pVXI
# 16  Ugxrmt_ZK6Ed4H1-KlB4AaABAg  04kJtp6pVXI
# ...

# %%
'''# empty list for storing reply
from ast import keyword


replies = []

# creating youtube resource object


# iterate video response
while video_response:
    
    # extracting required info
    # from each result object 
    for item in video_response['items']:
        
        # Extracting comments
        comment = item['snippet']['topLevelComment']['snippet']['textDisplay']
        keyWords = comment.lower().replace(' you ','y')
        # counting number of reply of comment
        replycount = item['snippet']['totalReplyCount']

        # if reply is there
        if replycount>0:
            
            # iterate through all reply
            for reply in item['replies']['comments']:
                
                # Extract reply
                reply = reply['snippet']['textDisplay']
                    
                # Store reply is list
                replies.append(reply)

        # print comment with list of reply
        print(comment, replies, end = '\n\n')

        # empty reply list
        replies = []
        
    # Again repeat
    if 'nextPageToken' in video_response:
        video_response = youtube.commentThreads().list(
                part = 'snippet,replies',
                videoId = "04kJtp6pVXI"
            ).execute()
    else:
        break'''
# Out:
# '# empty list for storing reply\nfrom ast import keyword\n\n\nreplies = []\n\n# creating youtube resource object\n\n\n# iterate video response\nwhile video_response:\n    \n    # extracting required info\n    # from each result object \n    for item in video_response[\'items\']:\n        \n        # Extracting comments\n        comment = item[\'snippet\'][\'topLevelComment\'][\'snippet\'][\'textDisplay\']\n        keyWords = comment.lower().replace(\' you \',\'y\')\n        # counting number of reply of comment\n        replycount = item[\'snippet\'][\'totalReplyCount\']\n\n        # if reply is there\n        if replycount>0:\n            \n            # iterate through all reply\n            for reply in item[\'replies\'][\'comments\']:\n                \n                # Extract reply\n                reply = reply[\'snippet\'][\'textDisplay\']\n                    \n                # Store reply is list\n                replies.append(reply)\n\n        # print comment with list 
# ...
